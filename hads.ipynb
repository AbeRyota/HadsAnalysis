# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2009 = pd.read_csv("hads2009RAW.csv")
df_2013 = pd.read_csv("hads2013RAW.csv")

# %%
df_2009.head()
# Out:
#           CONTROL  AGE1  ASSISTED  BEDRMS  BUILT METRO3  NUNITS   OTHERCOST  \
# 0  '100003130103'    87        -9       3   2006    '3'       1  310.000000
# 1  '100003130203'    70        -9       3   2006    '3'       1  222.750000
# 2  '100006370140'    48        -9       4   1985    '5'       1   79.166667
# 3  '100006520140'    62        -9       3   1985    '5'       1    0.000000
# 4  '100007130148'    30         0       2   1980    '1'       8    9.000000
#
#   OWNRENT  PER  ...   TOTSAL  TYPE     UTILITY  VACANCY   VALUE       WEIGHT  \
# 0     '1'    2  ...        0     1  229.166667       -6   50000  2772.262855
# 1     '1'    1  ...        0     1  355.416667       -6  238000  2876.223614
# 2     '1'    4  ...    58932     1  199.000000       -6  200000  2706.242657
# 3     '1'    2  ...        0     1  173.000000       -6  175000  2426.802292
# 4     '2'    2  ...    15600     1  113.000000       -6      -6  3089.847859
#
#    ZADEQ  ZINC2  ZSMHC   IPOV
# ...

# %%
print(df_2009.shape)
df_2009.describe()
# Out:
# (49090, 25)
#                AGE1      ASSISTED        BEDRMS         BUILT        NUNITS  \
# count  49090.000000  49090.000000  49090.000000  49090.000000  49090.000000
# mean      45.975494     -6.237217      2.731330   1966.605663     10.854655
# std       23.334608      4.203958      1.074593     26.548263     44.166826
# min       -9.000000     -9.000000      0.000000   1919.000000     -7.000000
# 25%       34.000000     -9.000000      2.000000   1950.000000      1.000000
# 50%       48.000000     -9.000000      3.000000   1970.000000      1.000000
# 75%       61.000000      0.000000      3.000000   1990.000000      2.000000
# max       93.000000      1.000000     10.000000   2009.000000    981.000000
#
#           OTHERCOST           PER         ROOMS  STRUCTURETYPE         TOTSAL  \
# count  49090.000000  49090.000000  49090.000000   49090.000000   49090.000000
# mean      65.146089      1.812508      5.659014       1.820208   45298.951212
# ...

# %%
df_2009.corr()
# Out:
#                    AGE1  ASSISTED    BEDRMS     BUILT    NUNITS  OTHERCOST  \
# AGE1           1.000000 -0.040759  0.113922 -0.041086 -0.015662   0.112570
# ASSISTED      -0.040759  1.000000 -0.428053 -0.095161  0.192787  -0.292295
# BEDRMS         0.113922 -0.428053  1.000000  0.119860 -0.279922   0.154554
# BUILT         -0.041086 -0.095161  0.119860  1.000000  0.039967   0.121942
# NUNITS        -0.015662  0.192787 -0.279922  0.039967  1.000000   0.036484
# OTHERCOST      0.112570 -0.292295  0.154554  0.121942  0.036484   1.000000
# PER            0.491999  0.123686  0.318511  0.023240 -0.119314   0.054953
# ROOMS          0.140514 -0.445404  0.863781  0.111247 -0.257757   0.188080
# STRUCTURETYPE -0.107222  0.337605 -0.458683  0.108909  0.438815  -0.039087
# TOTSAL        -0.015150 -0.155892  0.299408  0.112526 -0.071021   0.160862
# TYPE           0.007069 -0.009685 -0.052389  0.072227 -0.015894   0.011620
# ...
